# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
p = []
p.append(pd.read_csv('p10.txt', sep=' ', header=0))
p.append(pd.read_csv('p20.txt', sep=' ', header=0))
#p.append(pd.read_csv('p40.txt', sep=' ', header=0))
cases=len(p)
a10 = []
a10.append(pd.read_csv('paper_10_1.txt', sep = ' ', header = 0)) #1
a10.append(pd.read_csv('paper_10_2.txt', sep = ' ', header = 0)) #2
a10.append(pd.read_csv('paper_10_3.txt', sep = ' ', header = 0)) #3
a20 = []
a20.append(pd.read_csv('paper_20_1.txt', sep = ' ', header = 0)) #1
a20.append(pd.read_csv('paper_20_2.txt', sep = ' ', header = 0)) #2
a20.append(pd.read_csv('paper_20_3.txt', sep = ' ', header = 0)) #3
# Out:
# "\na20 = []\na20.append(pd.read_csv('paper_20_1.txt', sep = ' ', header = 0)) #1\na20.append(pd.read_csv('paper_20_2.txt', sep = ' ', header = 0)) #2\na20.append(pd.read_csv('paper_20_3.txt', sep = ' ', header = 0)) #3 "

# %%
print("Plaquette of L = 10, 20")
for i in range (cases):
    plt.plot(p[i].temperature, p[i].m, 'o', markersize=1, label=2**i*10)
plt.xlabel('T', fontsize=14)
plt.ylabel('$<m>$', fontsize=14)
plt.xlim(1.5, 3.5)
plt.ylim(0)
plt.legend()
plt.show()
for i in range (cases):
    plt.plot(p[i].temperature, p[i].ms, 'o', markersize=1, label=2**i*10)
plt.xlabel('T', fontsize=14)
plt.ylabel('$\chi$', fontsize=14)
plt.xlim(1.5, 3.5)
plt.legend()
plt.show()
for i in range (cases):
    plt.plot(p[i].temperature, p[i].e, 'o', markersize=1, label=2**i*10)
plt.xlabel('T', fontsize=14)
plt.ylabel('E', fontsize=14)
plt.xlim(1.5, 3.5)
plt.legend()
plt.show()
for i in range (cases):
    plt.plot(p[i].temperature, p[i].sp_h, 'o', markersize=1, label=2**i*10)
plt.xlabel('T', fontsize=14)
plt.ylabel('C', fontsize=14)
plt.xlim(1.5, 3.5)
plt.legend()
plt.show()

T_c = 2.493
for i in range (cases):
    plt.plot(p[i].temperature, 1-p[i].m4/(3*p[i].m2**2), '.', markersize=1, label=10*(1+i))
plt.axhline(y=0, color='k', linewidth=1, linestyle='--')
plt.axvline(x=T_c, color='k', linewidth=1, linestyle='--')
plt.xlim(1.5, 3.5)
plt.xlabel('T', fontsize=14)
plt.ylabel('$B_L$', fontsize=14)
plt.legend()
plt.show()
# Out:
# Plaquette of L = 10, 20

# %%
print("Plaquette & Fitted of L=10")
plt.plot(p[0].temperature, p[0].m, 'ro', markersize=1, label = 10)
for i in range (3):
    plt.plot(a10[i].temperature, a10[i].m, 'o', markersize=1, label=i+1)
plt.xlabel('T', fontsize=14)
plt.ylabel('$<m>$', fontsize=14)
plt.xlim(1.5, 3.5)
plt.ylim(0)
plt.legend()
plt.show()
plt.plot(p[0].temperature, p[0].ms, 'ro', markersize=1, label = 10)
for i in range (3):
    plt.plot(a10[i].temperature, a10[i].ms, 'o', markersize=1, label=i+1)
plt.xlabel('T', fontsize=14)
plt.ylabel('$\chi$', fontsize=14)
plt.xlim(1.5, 3.5)
plt.legend()
plt.show()
plt.plot(p[0].temperature, p[0].e, 'ro', markersize=1, label = 10)
for i in range (3):
    plt.plot(a10[i].temperature, a10[i].e, 'o', markersize=1, label=i+1)
plt.xlabel('T', fontsize=14)
plt.ylabel('$E$', fontsize=14)
plt.xlim(1.5, 3.5)
plt.legend()
plt.show()
plt.plot(p[0].temperature, p[0].sp_h, 'ro', markersize=1, label = 10)
for i in range (3):
    plt.plot(a10[i].temperature, a10[i].sp_h, 'o', markersize=1, label=i+1)
plt.xlabel('T', fontsize=14)
plt.ylabel('$C$', fontsize=14)
plt.xlim(1.5, 3.5)
plt.legend()
plt.show()

T_c = 2.493
plt.plot(p[0].temperature, 1-p[0].m4/(3*p[0].m2**2), 'ro', markersize=1, label=10*(1+i))
for i in range (cases2):
    plt.plot(a10[i].temperature, 1-a10[i].m4/(3*a10[i].m2**2), 'o', markersize=1, label=i+1)
plt.axhline(y=0, color='k', linewidth=1, linestyle='--')
plt.axvline(x=T_c, color='k', linewidth=1, linestyle='--')
plt.xlim(1.5, 3.5)
plt.xlabel('T', fontsize=14)
plt.ylabel('$B_L$', fontsize=14)
plt.legend()
plt.show()
# Out:
# Plaquette & Fitted of L=10

# %%
print("Plaquette & Fitted of L=20")
plt.plot(p[1].temperature, p[1].m, 'ro', markersize=1, label = 10)
for i in range (3):
    plt.plot(a20[i].temperature, a20[i].m, 'o', markersize=1, label=i+1)
plt.xlabel('T', fontsize=14)
plt.ylabel('$<m>$', fontsize=14)
plt.xlim(1.5, 3.5)
plt.ylim(0)
plt.legend()
plt.show()
plt.plot(p[1].temperature, p[1].ms, 'ro', markersize=1, label = 10)
for i in range (3):
    plt.plot(a20[i].temperature, a20[i].ms, 'o', markersize=1, label=i+1)
plt.xlabel('T', fontsize=14)
plt.ylabel('$\chi$', fontsize=14)
plt.xlim(1.5, 3.5)
plt.legend()
plt.show()
plt.plot(p[1].temperature, p[1].e, 'ro', markersize=1, label = 10)
for i in range (3):
    plt.plot(a20[i].temperature, a20[i].e, 'o', markersize=1, label=i+1)
plt.xlabel('T', fontsize=14)
plt.ylabel('$E$', fontsize=14)
plt.xlim(1.5, 3.5)
plt.legend()
plt.show()
plt.plot(p[1].temperature, p[1].sp_h, 'ro', markersize=1, label = 10)
for i in range (3):
    plt.plot(a20[i].temperature, a20[i].sp_h, 'o', markersize=1, label=i+1)
plt.xlabel('T', fontsize=14)
plt.ylabel('$C$', fontsize=14)
plt.xlim(1.5, 3.5)
plt.legend()
plt.show()

T_c = 2.493
plt.plot(p[1].temperature, 1-p[1].m4/(3*p[0].m2**2), 'ro', markersize=1, label=10*(1+i))
for i in range (cases2):
    plt.plot(a20[i].temperature, 1-a20[i].m4/(3*a20[i].m2**2), 'o', markersize=1, label=i+1)
plt.axhline(y=0, color='k', linewidth=1, linestyle='--')
plt.axvline(x=T_c, color='k', linewidth=1, linestyle='--')
plt.xlim(1.5, 3.5)
plt.xlabel('T', fontsize=14)
plt.ylabel('$B_L$', fontsize=14)
plt.legend()
plt.show()
