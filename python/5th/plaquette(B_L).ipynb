# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
p = []
p.append(pd.read_csv('p10.txt', sep=' ', header=0))
#p.append(pd.read_csv('p20.txt', sep=' ', header=0))
#p.append(pd.read_csv('p40.txt', sep=' ', header=0))
cases=len(p)
a = []
a.append(pd.read_csv('paper_origin_1.txt', sep = ' ', header = 0)) #1
a.append(pd.read_csv('paper_origin_2.txt', sep = ' ', header = 0)) #2
a.append(pd.read_csv('paper_origin_3.txt', sep = ' ', header = 0)) #3
cases2 = len(a)

# %%
for i in range (cases):
    plt.plot(p[i].temperature, p[i].m, 'o', markersize=1, label=2**i*10)
for i in range (cases2):
    plt.plot(a[i].temperature, a[i].m, 'o', markersize=1, label=i+1)
plt.plot
plt.xlabel('T', fontsize=14)
plt.ylabel('$<m>$', fontsize=14)
plt.xlim(1.5, 3.5)
plt.ylim(0)
plt.legend()
plt.show()

# %%
for i in range (cases):
    plt.plot(p[i].temperature, p[i].mag_sus, 'o', markersize=1, label=2**i*10)
for i in range (cases2):
    plt.plot(a[i].temperature, a[i].mag_sus, 'o', markersize=1, label=i+1)
plt.plot(q1.temperature, q1.mag_sus, '.', markersize=1)
plt.xlabel('T', fontsize=14)
plt.ylabel('$\chi$', fontsize=14)
plt.xlim(1.5, 3.5)
plt.legend()
plt.show()

# %%
T_c = 2.493
for i in range (cases):
    plt.plot(p[i].temperature, 1-p[i].m4/(3*p[i].m2**2), 'o', markersize=1, label=10*(1+i))
for i in range (cases2):
    plt.plot(a[i].temperature, 1-a[i].m4/(3*a[i].m2**2), 'o', markersize=1, label=i+1)
plt.plot(q1.temperature, 1-q1.m4/(3*q1.m2**2), '.', markersize=1)
plt.axhline(y=0, color='k', linewidth=1, linestyle='--')
plt.axvline(x=T_c, color='k', linewidth=1, linestyle='--')
plt.xlim(1.5, 3.5)
plt.xlabel('T', fontsize=14)
plt.ylabel('$B_L$', fontsize=14)
plt.legend()
plt.show()
T_c = 2.493
for i in range (cases):
    plt.plot(p[i].temperature, 1-p[i].m4/(3*p[i].m2**2), '.', markersize=1, label=10*(1+i))
plt.axhline(y=0, color='k', linewidth=1, linestyle='--')
plt.axvline(x=T_c, color='k', linewidth=1, linestyle='--')
plt.xlim(2.42, 2.575)
plt.ylim(0.55, 0.65)
plt.xlabel('T', fontsize=14)
plt.ylabel('$B_L$', fontsize=14)
plt.legend()
plt.show()

# %%
for i in range (cases):
    plt.plot(p[i].temperature, p[i].sp_heat, 'o', markersize=1, label=2**i*10)
for i in range (cases2):
    plt.plot(a[i].temperature, a[i].sp_heat, 'o', markersize=1, label=i+1)
plt.legend()
plt.show()
for i in range (cases):
    plt.plot(p[i].temperature, p[i].e, 'o', markersize=1, label=2**i*10)
for i in range (cases2):
    plt.plot(a[i].temperature, a[i].e, 'o', markersize=1, label=i+1)
plt.legend()
plt.show()
