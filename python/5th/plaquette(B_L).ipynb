# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
p = []
p.append(pd.read_csv('plaquette_m1.txt', sep=' ', header=0))
p.append(pd.read_csv('plaquette_m2.txt', sep=' ', header=0))
cases=len(p)

q1 = pd.read_csv('fileout.txt', sep=' ', header=0)
q2 = pd.read_csv('fileout2.txt', sep=' ', header=0)

# %%
for i in range (cases):
    plt.plot(p[i].temperature, p[i].m, '.', markersize=1, label=10*(1+i))
plt.plot(q1.temperature, q1.m, '.', markersize=1)
plt.plot(q2.temperature, q2.m, '.', markersize=1)
plt.xlabel('T', fontsize=14)
plt.ylabel('$<m>$', fontsize=14)
plt.xlim(1.5, 3.5)
plt.ylim(0)
plt.legend()
plt.show()

# %%
for i in range (cases):
    plt.plot(p[i].temperature, p[i].mag_sus, '.', markersize=1, label=10*(1+i))
plt.plot(q1.temperature, q1.mag_sus, '.', markersize=1)
plt.plot(q2.temperature, q2.mag_sus, '.', markersize=1)
plt.xlabel('T', fontsize=14)
plt.ylabel('$\chi$', fontsize=14)
plt.xlim(1.5, 3.5)
plt.legend()
plt.show()

# %%
T_c = 2.493
for i in range (cases):
    plt.plot(p[i].temperature, 1-p[i].m4/(3*p[i].m2**2), '.', markersize=1, label=10*(1+i))
plt.plot(q1.temperature, 1-q1.m4/(3*q1.m2**2), '.', markersize=1)
plt.plot(q2.temperature, 1-q2.m4/(3*q2.m2**2), '.', markersize=1)
plt.axhline(y=0, color='k', linewidth=1, linestyle='--')
plt.axvline(x=T_c, color='k', linewidth=1, linestyle='--')
plt.xlim(1.5, 3.5)
plt.xlabel('T', fontsize=14)
plt.ylabel('$B_L$', fontsize=14)
plt.legend()
plt.show()
T_c = 2.493
for i in range (cases):
    plt.plot(p[i].temperature, 1-p[i].m4/(3*p[i].m2**2), '.', markersize=1, label=10*(1+i))
plt.axhline(y=0, color='k', linewidth=1, linestyle='--')
plt.axvline(x=T_c, color='k', linewidth=1, linestyle='--')
plt.xlim(2.42, 2.575)
plt.ylim(0.55, 0.65)
plt.xlabel('T', fontsize=14)
plt.ylabel('$B_L$', fontsize=14)
plt.legend()
plt.show()
