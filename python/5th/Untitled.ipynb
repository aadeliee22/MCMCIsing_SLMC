# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
f=[]
f.append(pd.read_csv('clustersize_10.txt', sep=' ', header=0))
f.append(pd.read_csv('clustersize_20.txt', sep=' ', header=0))
casesf=len(f)
g=[]
g.append(pd.read_csv('clustersize_10_2.txt', sep=' ', header=0))
g.append(pd.read_csv('clustersize_20_2.txt', sep=' ', header=0))
casesg=len(g)

# %%
for i in range (casesf):
    plt.plot(f[i].temp, 100*(1+i)**2 / f[i].cl_size, '.', label=10*(1+i))
for i in range (casesg):
    plt.plot(g[i].temp, 100*(1+i)**2 / g[i].cl_size, '.', label=-10*(1+i))
plt.xlim(2)
plt.legend()
plt.show()

# %%
h = pd.read_csv('clustersize_J2.txt', sep=' ', header=0)
for i in range (9):
    plt.plot(h.temp[41*i:41*i+41], 400/h.cl_size[41*i:41*i+41], '.', label=-0.2+0.05*i)
    print(h.cl_size[41*i+40])
plt.xlim(2.2, 3.5)
plt.ylim(1, 50)
plt.show()
# Out:
# 2.8412
# 2.8488
# 2.867
# 2.8352
# 2.8196
# 3.1324
# 3.4844
# 3.9882
# 4.44

# %%
for i in range (9):
    plt.plot(i, h.cl_size[41*i+40], '.')

# %%
hh = pd.read_csv('clustersize_J1.txt', sep=' ', header=0)
for i in range (9):
    plt.plot(hh.temp[41*i:41*i+41], 400/hh.cl_size[41*i:41*i+41], '.-', label=0.8+0.05*i)
    print(hh.cl_size[41*i+40])
plt.xlim(1.8, 3.2)
plt.ylim(2, 50)
plt.legend()
plt.show()
# Out:
# 2.1776
# 2.325
# 2.5562
# 2.608
# 2.861
# 3.0304
# 3.3762
# 3.6006
# 4.033

# %%
for i in range (9):
    print(2.3*(0.8+0.05*i))
# Out:
# 1.8399999999999999
# 1.955
# 2.07
# 2.185
# 2.3
# 2.415
# 2.53
# 2.645
# 2.7600000000000002
